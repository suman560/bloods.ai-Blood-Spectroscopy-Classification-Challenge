# %%
import pandas  as pd

# %%
train = pd.read_csv('Update_train.csv')

# %%
final_train=train.groupby(['donation_id','hdl_cholesterol_human','hemoglobin(hgb)_human','cholesterol_ldl_human']).mean()

# %%
final_train.to_csv("Final_train.csv",index=True)

# %%
###test

# %%
test = pd.read_csv('Updated_Test.csv')

# %%
test.head()
# Out:
#     Reading_ID donation_id  absorbance0  absorbance1  absorbance2  \
# 0  ID_KWUAQLRM     ID_2982     0.517951     0.520508     0.526852
# 1  ID_FN8SIVJJ     ID_2982     0.517839     0.522367     0.525186
# 2  ID_CI4TQCHI     ID_2982     0.517702     0.522018     0.527237
# 3  ID_URJMKNU7     ID_2982     0.525008     0.527439     0.536871
# 4  ID_HBJH67IS     ID_2982     0.520532     0.522683     0.526842
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.531611     0.536816     0.543828     0.547761     0.554379  ...
# 1     0.534661     0.541900     0.546180     0.551687     0.556753  ...
# 2     0.534374     0.541155     0.547152     0.549837     0.557513  ...
# 3     0.539636     0.546555     0.553183     0.558826     0.563549  ...
# 4     0.534634     0.539676     0.547488     0.552688     0.558355  ...
#
#    absorbance164  absorbance165  absorbance166  absorbance167  absorbance168  \
# ...

# %%
test.drop(["Reading_ID"], axis=1, inplace=True)

# %%
test.head()
# Out:
#   donation_id  absorbance0  absorbance1  absorbance2  absorbance3  \
# 0     ID_2982     0.517951     0.520508     0.526852     0.531611
# 1     ID_2982     0.517839     0.522367     0.525186     0.534661
# 2     ID_2982     0.517702     0.522018     0.527237     0.534374
# 3     ID_2982     0.525008     0.527439     0.536871     0.539636
# 4     ID_2982     0.520532     0.522683     0.526842     0.534634
#
#    absorbance4  absorbance5  absorbance6  absorbance7  absorbance8  ...  \
# 0     0.536816     0.543828     0.547761     0.554379     0.565622  ...
# 1     0.541900     0.546180     0.551687     0.556753     0.566446  ...
# 2     0.541155     0.547152     0.549837     0.557513     0.566793  ...
# 3     0.546555     0.553183     0.558826     0.563549     0.575675  ...
# 4     0.539676     0.547488     0.552688     0.558355     0.568959  ...
#
#    absorbance164  absorbance165  absorbance166  absorbance167  absorbance168  \
# ...

# %%
final_test=test.groupby(['donation_id']).mean()

# %%
final_test.shape
# Out:
# (61, 174)

# %%
final_test.head()
# Out:
#              absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# donation_id
# ID_1961         0.499920     0.504608     0.507929     0.519943     0.529032
# ID_2067         0.497758     0.498091     0.503083     0.507249     0.513739
# ID_2155         0.551436     0.553079     0.556722     0.560722     0.565583
# ID_2211         0.525926     0.528948     0.532222     0.540022     0.547279
# ID_2327         0.559814     0.559612     0.561561     0.565162     0.567556
#
#              absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  \
# donation_id
# ID_1961         0.536118     0.539690     0.541710     0.548590     0.560742
# ID_2067         0.521944     0.528798     0.533743     0.541470     0.551838
# ID_2155         0.570889     0.578668     0.585142     0.594233     0.610121
# ID_2211         0.554348     0.558680     0.563768     0.570031     0.583540
# ID_2327         0.572362     0.579762     0.587761     0.599415     0.615964
#
# ...

# %%
final_test.drop(["id"], axis=1, inplace=True)
final_test.drop(["std"], axis=1, inplace=True)

# %%
final_test.head()
# Out:
#              absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# donation_id
# ID_1961         0.499920     0.504608     0.507929     0.519943     0.529032
# ID_2067         0.497758     0.498091     0.503083     0.507249     0.513739
# ID_2155         0.551436     0.553079     0.556722     0.560722     0.565583
# ID_2211         0.525926     0.528948     0.532222     0.540022     0.547279
# ID_2327         0.559814     0.559612     0.561561     0.565162     0.567556
#
#              absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  \
# donation_id
# ID_1961         0.536118     0.539690     0.541710     0.548590     0.560742
# ID_2067         0.521944     0.528798     0.533743     0.541470     0.551838
# ID_2155         0.570889     0.578668     0.585142     0.594233     0.610121
# ID_2211         0.554348     0.558680     0.563768     0.570031     0.583540
# ID_2327         0.572362     0.579762     0.587761     0.599415     0.615964
#
# ...

# %%
final_test.shape
# Out:
# (61, 173)

# %%
final_test.to_csv("Final_Test.csv",index=True)
