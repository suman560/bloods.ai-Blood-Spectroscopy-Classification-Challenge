# %%
import os
import pandas as pd
import numpy as np
import json
import random, string
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
maindir = "./" # Directory with your files
train1_loc= maindir+"/Final_Train.csv"
train2_loc= maindir+"/Additional_hdl_rows_162_LOW_STD.csv"
#train3_loc= maindir+"/No_NULL_Exports_hdl_rows_483_full.csv"
# testcsv = maindir+"/Final_Test2.csv"

# %%
train1 = pd.read_csv(train1_loc)
train2 = pd.read_csv(train2_loc)
#train3 = pd.read_csv(train3_loc)

# %%
train2.isnull().values.any()

# %%
train1.head()

# %%
train1.drop(["id"], axis=1, inplace=True)
train1.drop(["std"], axis=1, inplace=True)

# %%
train1.drop(["hemoglobin(hgb)_human"], axis=1, inplace=True)
train1.drop(["cholesterol_ldl_human"], axis=1, inplace=True)

# %%
train1.head()
# Out:
#    donation_id hdl_cholesterol_human  absorbance0  absorbance1  absorbance2  \
# 0         1975                   low     0.505055     0.506570     0.511544
# 1         1982                   low     0.523531     0.523485     0.526291
# 2         1989                   low     0.516449     0.519226     0.523619
# 3         1994                   low     0.512397     0.514371     0.518486
# 4         2002                   low     0.496008     0.496698     0.499643
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.516300     0.524067     0.530191     0.536138     0.542317  ...
# 1     0.532875     0.538397     0.543180     0.547520     0.553433  ...
# 2     0.532366     0.540438     0.547985     0.552716     0.556823  ...
# 3     0.520868     0.526911     0.534963     0.542428     0.549013  ...
# 4     0.502549     0.506363     0.511604     0.518730     0.523823  ...
#
# ...

# %%
train2.head()
# Out:
#    donation_id hdl_cholesterol_human  absorbance0  absorbance1  absorbance2  \
# 0         1974                   low     0.502636     0.506272     0.509749
# 1         1999                   low     0.576990     0.576752     0.583474
# 2         2001                   low     0.562941     0.563152     0.570033
# 3         2021                    ok     0.524103     0.524649     0.528271
# 4         2024                    ok     0.487408     0.487817     0.491583
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.513453     0.517903     0.523063     0.529182     0.536420  ...
# 1     0.588204     0.595724     0.602002     0.608842     0.611728  ...
# 2     0.574368     0.583060     0.590106     0.597707     0.600610  ...
# 3     0.533941     0.541959     0.549013     0.556098     0.561205  ...
# 4     0.497077     0.505775     0.513154     0.519818     0.523342  ...
#
# ...

# %%
train2.drop(["scan_number"], axis=1, inplace=True)
train2.drop(["std"], axis=1, inplace=True)
train2.drop(["hdl_cholesterol_value"], axis=1, inplace=True)

# %%
train2.shape
# Out:
# (162, 174)

# %%
train3.head()

# %%
train3.drop(["scan_number"], axis=1, inplace=True)
train3.drop(["std"], axis=1, inplace=True)
train3.drop(["hdl_cholesterol_value"], axis=1, inplace=True)

# %%
train3.shape

# %%
train1.shape
# Out:
# (486, 174)

# %%
train2.shape
# Out:
# (162, 174)

# %%
super_final = pd.concat([train1,train2]).reset_index(drop = True)

# %%
super_final.shape
# Out:
# (648, 174)

# %%
super_final.head()
# Out:
#    donation_id hdl_cholesterol_human  absorbance0  absorbance1  absorbance2  \
# 0         1975                   low     0.505055     0.506570     0.511544
# 1         1982                   low     0.523531     0.523485     0.526291
# 2         1989                   low     0.516449     0.519226     0.523619
# 3         1994                   low     0.512397     0.514371     0.518486
# 4         2002                   low     0.496008     0.496698     0.499643
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.516300     0.524067     0.530191     0.536138     0.542317  ...
# 1     0.532875     0.538397     0.543180     0.547520     0.553433  ...
# 2     0.532366     0.540438     0.547985     0.552716     0.556823  ...
# 3     0.520868     0.526911     0.534963     0.542428     0.549013  ...
# 4     0.502549     0.506363     0.511604     0.518730     0.523823  ...
#
# ...

# %%
super_final.to_csv("hdl_low_std.csv",index=False)

# %%
x = pd.read_csv("hdl_low_std.csv")

# %%
x.shape
# Out:
# (648, 174)

# %%
x.head()
# Out:
#    donation_id hdl_cholesterol_human  absorbance0  absorbance1  absorbance2  \
# 0         1975                   low     0.505055     0.506570     0.511544
# 1         1982                   low     0.523531     0.523485     0.526291
# 2         1989                   low     0.516449     0.519226     0.523619
# 3         1994                   low     0.512397     0.514371     0.518486
# 4         2002                   low     0.496008     0.496698     0.499643
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.516300     0.524067     0.530191     0.536138     0.542317  ...
# 1     0.532875     0.538397     0.543180     0.547520     0.553433  ...
# 2     0.532366     0.540438     0.547985     0.552716     0.556823  ...
# 3     0.520868     0.526911     0.534963     0.542428     0.549013  ...
# 4     0.502549     0.506363     0.511604     0.518730     0.523823  ...
#
# ...

# %%
x.isnull().values.any()
# Out:
# False
