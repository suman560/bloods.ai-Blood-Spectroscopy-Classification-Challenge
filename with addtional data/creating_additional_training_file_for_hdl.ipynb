# %%
import pandas as pd

# %%
temp1= pd.read_csv("Exports_hdl_rows_162_full.csv")

# %%
temp1.head()
# Out:
#    donation_id  scan_number  \
# 0        10841            1
# 1        10841            2
# 2        10841            3
# 3        10841            4
# 4        10841            5
#
#                                           absorbance     std  temperature  \
# 0  0.52281813260482 0.51949219725263 0.5264422548...  0.0056        42.38
# 1  0.51923144372845 0.52235175972796 0.5229065445...  0.0056        42.48
# 2  0.51721320908433 0.51849578207502 0.5245591625...  0.0056        42.58
# 3  0.52022670958475 0.52037868958736 0.5269751029...  0.0056        42.68
# 4  0.51708666137411 0.52161464343642 0.5267039231...  0.0056        42.75
#
#    humidity hdl_cholesterol_human  hdl_cholesterol_value
# 0     45.58                   low                   42.2
# 1     45.47                   low                   42.2
# 2     45.37                   low                   42.2
# 3     45.32                   low                   42.2
# 4     45.21                   low                   42.2

# %%
temp1.shape
# Out:
# (9720, 8)

# %%
print (temp1['absorbance'].dtypes)
# Out:
# object

# %%
temp2= temp1["absorbance"]

# %%
temp2.dtypes
# Out:
# dtype('O')

# %%
temp2.to_csv("without_comma.csv",index=False,header=False)

# %%
r= pd.read_csv("without_comma.csv",delimiter=' ')

# %%
r.head()
# Out:
#    0.52281813260482  0.51949219725263  0.52644225488987  0.53244394889525  \
# 0          0.519231          0.522352          0.522907          0.529875
# 1          0.517213          0.518496          0.524559          0.529592
# 2          0.520227          0.520379          0.526975          0.532377
# 3          0.517087          0.521615          0.526704          0.527695
# 4          0.516087          0.519380          0.523157          0.528692
#
#    0.5353222923604  0.54406435442923  0.54939592767421  0.55264205767993  \
# 0         0.535889          0.541123          0.546886          0.550454
# 1         0.536908          0.541784          0.545905          0.551181
# 2         0.536789          0.543567          0.546632          0.550731
# 3         0.534110          0.542949          0.547859          0.550538
# 4         0.535801          0.541566          0.545905          0.549429
#
#    0.55808447097365  0.56886333734348  ...  1.2637816726674  1.2645003562689  \
# ...

# %%
r.isnull().values.any()
# Out:
# False

# %%
r.shape
# Out:
# (9719, 170)

# %%
r.to_csv('with_comma.csv',index=False)

# %%
g= pd.read_csv('with_comma.csv',header=None)

# %%
g.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.522818  0.519492  0.526442  0.532444  0.535322  0.544064  0.549396
# 1  0.519231  0.522352  0.522907  0.529875  0.535889  0.541123  0.546886
# 2  0.517213  0.518496  0.524559  0.529592  0.536908  0.541784  0.545905
# 3  0.520227  0.520379  0.526975  0.532377  0.536789  0.543567  0.546632
# 4  0.517087  0.521615  0.526704  0.527695  0.534110  0.542949  0.547859
#
#         7         8         9    ...       160       161       162       163  \
# 0  0.552642  0.558084  0.568863  ...  1.263782  1.264500  1.260582  1.241527
# 1  0.550454  0.558756  0.567580  ...  1.264688  1.263147  1.247994  1.243765
# 2  0.551181  0.558595  0.566122  ...  1.262554  1.258289  1.251042  1.247328
# 3  0.550731  0.559143  0.568397  ...  1.253993  1.258872  1.261109  1.241730
# 4  0.550538  0.559549  0.567221  ...  1.258157  1.256204  1.256531  1.243235
#
#         164       165       166       167       168       169
# ...

# %%
l =[]

# %%
for i in range(170):
    a = "absorbance" + str(i) 
    l.append(a)

# %%
df = pd.DataFrame(columns=l)

# %%
df.to_csv("dff1.csv",index=False)

# %%
x = pd.read_csv('dff1.csv',header=None)

# %%
ndf = pd.concat([x, g]).reset_index(drop = True)

# %%
ndf.head()
# Out:
#            0            1            2            3            4    \
# 0  absorbance0  absorbance1  absorbance2  absorbance3  absorbance4
# 1     0.522818     0.519492     0.526442     0.532444     0.535322
# 2     0.519231     0.522352     0.522907     0.529875     0.535889
# 3     0.517213     0.518496     0.524559     0.529592     0.536908
# 4     0.520227     0.520379     0.526975     0.532377     0.536789
#
#            5            6            7            8            9    ...  \
# 0  absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...
# 1     0.544064     0.549396     0.552642     0.558084     0.568863  ...
# 2     0.541123     0.546886     0.550454     0.558756      0.56758  ...
# 3     0.541784     0.545905     0.551181     0.558595     0.566122  ...
# 4     0.543567     0.546632     0.550731     0.559143     0.568397  ...
#
#              160            161            162            163            164  \
# ...

# %%
ndf.to_csv('absorbance.csv',index=False,header=False)

# %%
absor = pd.read_csv('absorbance.csv')

# %%
absor.head()
# Out:
#    absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# 0     0.522818     0.519492     0.526442     0.532444     0.535322
# 1     0.519231     0.522352     0.522907     0.529875     0.535889
# 2     0.517213     0.518496     0.524559     0.529592     0.536908
# 3     0.520227     0.520379     0.526975     0.532377     0.536789
# 4     0.517087     0.521615     0.526704     0.527695     0.534110
#
#    absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# 0     0.544064     0.549396     0.552642     0.558084     0.568863  ...
# 1     0.541123     0.546886     0.550454     0.558756     0.567580  ...
# 2     0.541784     0.545905     0.551181     0.558595     0.566122  ...
# 3     0.543567     0.546632     0.550731     0.559143     0.568397  ...
# 4     0.542949     0.547859     0.550538     0.559549     0.567221  ...
#
#    absorbance160  absorbance161  absorbance162  absorbance163  absorbance164  \
# ...

# %%
absor.shape
# Out:
# (9720, 170)

# %%
c1 = pd.read_csv("Exports_hdl_rows_162_full.csv")

# %%
c1.shape
# Out:
# (9720, 8)

# %%
c1.drop(["absorbance"], axis=1, inplace=True)

# %%
c1.head()
# Out:
#    donation_id  scan_number     std  temperature  humidity  \
# 0        10841            1  0.0056        42.38     45.58
# 1        10841            2  0.0056        42.48     45.47
# 2        10841            3  0.0056        42.58     45.37
# 3        10841            4  0.0056        42.68     45.32
# 4        10841            5  0.0056        42.75     45.21
#
#   hdl_cholesterol_human  hdl_cholesterol_value
# 0                   low                   42.2
# 1                   low                   42.2
# 2                   low                   42.2
# 3                   low                   42.2
# 4                   low                   42.2

# %%
c2=pd.read_csv("absorbance.csv")

# %%
c3 = pd.concat([c2, c1],axis=1)

# %%
c3.head()
# Out:
#    absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# 0     0.522818     0.519492     0.526442     0.532444     0.535322
# 1     0.519231     0.522352     0.522907     0.529875     0.535889
# 2     0.517213     0.518496     0.524559     0.529592     0.536908
# 3     0.520227     0.520379     0.526975     0.532377     0.536789
# 4     0.517087     0.521615     0.526704     0.527695     0.534110
#
#    absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# 0     0.544064     0.549396     0.552642     0.558084     0.568863  ...
# 1     0.541123     0.546886     0.550454     0.558756     0.567580  ...
# 2     0.541784     0.545905     0.551181     0.558595     0.566122  ...
# 3     0.543567     0.546632     0.550731     0.559143     0.568397  ...
# 4     0.542949     0.547859     0.550538     0.559549     0.567221  ...
#
#    absorbance167  absorbance168  absorbance169  donation_id  scan_number  \
# ...

# %%
c3.shape
# Out:
# (9720, 177)

# %%
c3.to_csv('final_additional_hdl.csv',index=False)

# %%
tt= pd.read_csv('final_additional_hdl.csv')

# %%
tt.head()
# Out:
#    absorbance0  absorbance1  absorbance2  absorbance3  absorbance4  \
# 0     0.522818     0.519492     0.526442     0.532444     0.535322
# 1     0.519231     0.522352     0.522907     0.529875     0.535889
# 2     0.517213     0.518496     0.524559     0.529592     0.536908
# 3     0.520227     0.520379     0.526975     0.532377     0.536789
# 4     0.517087     0.521615     0.526704     0.527695     0.534110
#
#    absorbance5  absorbance6  absorbance7  absorbance8  absorbance9  ...  \
# 0     0.544064     0.549396     0.552642     0.558084     0.568863  ...
# 1     0.541123     0.546886     0.550454     0.558756     0.567580  ...
# 2     0.541784     0.545905     0.551181     0.558595     0.566122  ...
# 3     0.543567     0.546632     0.550731     0.559143     0.568397  ...
# 4     0.542949     0.547859     0.550538     0.559549     0.567221  ...
#
#    absorbance167  absorbance168  absorbance169  donation_id  scan_number  \
# ...

# %%
tt.shape
# Out:
# (9720, 177)

# %%
final_train_additional_hdl=tt.groupby(['donation_id','hdl_cholesterol_human']).mean()

# %%
final_train_additional_hdl.head()
# Out:
#                                    absorbance0  absorbance1  absorbance2  \
# donation_id hdl_cholesterol_human
# 1974        low                       0.502636     0.506272     0.509749
# 1999        low                       0.576990     0.576752     0.583474
# 2001        low                       0.562941     0.563152     0.570033
# 2021        ok                        0.524103     0.524649     0.528271
# 2024        ok                        0.487408     0.487817     0.491583
#
#                                    absorbance3  absorbance4  absorbance5  \
# donation_id hdl_cholesterol_human
# 1974        low                       0.513453     0.517903     0.523063
# 1999        low                       0.588204     0.595724     0.602002
# 2001        low                       0.574368     0.583060     0.590106
# 2021        ok                        0.533941     0.541959     0.549013
# 2024        ok                        0.497077     0.505775     0.513154
#
# ...

# %%
final_train_additional_hdl.to_csv("Additional_hdl_rows_162_LOW_STD.csv",index=True)

# %%
y = pd.read_csv('Additional_hdl_rows_162_LOW_STD.csv')

# %%
y.head()
# Out:
#    donation_id hdl_cholesterol_human  absorbance0  absorbance1  absorbance2  \
# 0         1974                   low     0.502636     0.506272     0.509749
# 1         1999                   low     0.576990     0.576752     0.583474
# 2         2001                   low     0.562941     0.563152     0.570033
# 3         2021                    ok     0.524103     0.524649     0.528271
# 4         2024                    ok     0.487408     0.487817     0.491583
#
#    absorbance3  absorbance4  absorbance5  absorbance6  absorbance7  ...  \
# 0     0.513453     0.517903     0.523063     0.529182     0.536420  ...
# 1     0.588204     0.595724     0.602002     0.608842     0.611728  ...
# 2     0.574368     0.583060     0.590106     0.597707     0.600610  ...
# 3     0.533941     0.541959     0.549013     0.556098     0.561205  ...
# 4     0.497077     0.505775     0.513154     0.519818     0.523342  ...
#
# ...

# %%
y.shape
# Out:
# (162, 177)

# %%
9720/60
# Out:
# 162.0
